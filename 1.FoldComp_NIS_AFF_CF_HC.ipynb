# %%
import sys
import os

# Añadir la ruta a sys.path
module_path = r'C:/Users/Admin/FoldComparative_cf2024/AlphaFoldXplore_cf2024'
if module_path not in sys.path:
    sys.path.append(module_path)

# Ahora importa el módulo de librerias a implementar: 
import fold_comparative as fc
import alphafoldxplore as fx
# Out:
# No estás en Google Colab. Algunas funcionalidades estarán limitadas.
# ['c:\\Users\\Admin\\AppData\\Local\\Programs\\Python\\Python312\\python312.zip', 'c:\\Users\\Admin\\AppData\\Local\\Programs\\Python\\Python312\\DLLs', 'C:/Users/Admin/FoldComparative_cf2024', 'c:\\Users\\Admin\\AppData\\Local\\Programs\\Python\\Python312\\Lib', 'c:\\Users\\Admin\\AppData\\Local\\Programs\\Python\\Python312', '', 'C:\\Users\\Admin\\AppData\\Roaming\\Python\\Python312\\site-packages', 'C:\\Users\\Admin\\AppData\\Roaming\\Python\\Python312\\site-packages\\win32', 'C:\\Users\\Admin\\AppData\\Roaming\\Python\\Python312\\site-packages\\win32\\lib', 'C:\\Users\\Admin\\AppData\\Roaming\\Python\\Python312\\site-packages\\Pythonwin', 'c:\\Users\\Admin\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages', 'C:/Users/Admin/FoldComparative_cf2024/AlphaFoldXplore_cf2024', 'C:/Users/Admin/FoldComparative_cf2024']
# No estás en Google Colab. Algunas funcionalidades estarán limitadas.
# ...

# %%
#Importando rutas de afxt
afxt_paths = [
   'C:/Users/Admin/FoldComparative_cf2024/input/1.NIS_ColabFold_PREDICHAS-20240917T061608Z-001/NIS_part__1_20240422142541.afxt',
    'C:/Users/Admin/FoldComparative_cf2024/input/1.NIS_ColabFold_PREDICHAS-20240917T061608Z-001/NIS_part__2_20240422170547.afxt',
   'C:/Users/Admin/FoldComparative_cf2024/input/1.NIS_ColabFold_PREDICHAS-20240917T061608Z-001/NIS_part__3_20240422172020.afxt',
    'C:/Users/Admin/FoldComparative_cf2024/input/1.NIS_ColabFold_PREDICHAS-20240917T061608Z-001/NIS_part__4_20240422181735.afxt',
   'C:/Users/Admin/FoldComparative_cf2024/input/1.NIS_ColabFold_PREDICHAS-20240917T061608Z-001/NIS_part__5_20240422172612.afxt',
    'C:/Users/Admin/FoldComparative_cf2024/input/1.NIS_ColabFold_PREDICHAS-20240917T061608Z-001/NIS_part__6_20240422181937.afxt',
    'C:/Users/Admin/FoldComparative_cf2024/input/1.NIS_ColabFold_PREDICHAS-20240917T061608Z-001/NIS_part__7_20240423095449.afxt',
    'C:/Users/Admin/FoldComparative_cf2024/input/1.NIS_ColabFold_PREDICHAS-20240917T061608Z-001/NIS_part__8_20240422210337.afxt',
    'C:/Users/Admin/FoldComparative_cf2024/input/1.NIS_ColabFold_PREDICHAS-20240917T061608Z-001/NIS_part__9_20240423113659.afxt',
    'C:/Users/Admin/FoldComparative_cf2024/input/1.NIS_ColabFold_PREDICHAS-20240917T061608Z-001/NIS_part__10_20240422214112.afxt',
    'C:/Users/Admin/FoldComparative_cf2024/input/1.NIS_ColabFold_PREDICHAS-20240917T061608Z-001/NIS_part__11_20240423190809.afxt',
    'C:/Users/Admin/FoldComparative_cf2024/input/1.NIS_ColabFold_PREDICHAS-20240917T061608Z-001/NIS_part__12_20240423203122.afxt',
    'C:/Users/Admin/FoldComparative_cf2024/input/1.NIS_ColabFold_PREDICHAS-20240917T061608Z-001/NIS_part__13_20240422235018.afxt',
    'C:/Users/Admin/FoldComparative_cf2024/input/1.NIS_ColabFold_PREDICHAS-20240917T061608Z-001/NIS_part__14_20240423164053.afxt'
]
#mismo objeto para aplicar funcion get_pTMscore*

# %%
# import pandas as pd
# pTMscore_data = fc.get_pTMscore(afxt_paths)
# pTMscore_data['p'] = [f'p{i+1}' for i in range(199)]
# #Curado da datos a comparar: 
# order_key=['p115','p13','p105','p102','p101','p106','p103','p104', 'p107', 'p108', 'p110', 'p109', 'p147', 'p34', 'p71', 'p85', 'p66', 'p139', 'p178', 'p177', 'p176', 'p175', 'p12', 'p28', 'p31', 'p32', 'p112', 'p111', 'p120', 'p116', 'p123', 'p117', 'p121', 'p118', 'p119', 'p122', 'p124', 'p145', 'p146', 'p183', 'p184', 'p185', 'p186', 'p16', 'p33', 'p182', 'p187', 'p26', 'p27', 'p132', 'p126', 'p130', 'p127', 'p125', 'p128', 'p129', 'p131', 'p153', 'p158', 'p155', 'p160', 'p161', 'p159', 'p157', 'p156', 'p154', 'p162', 'p166', 'p163', 'p164', 'p167', 'p165', 'p179', 'p29', 'p97', 'p100', 'p15', 'p84', 'p67', 'p180', 'p23', 'p22', 'p18', 'p20', 'p24', 'p21', 'p19', 'p17', 'p25', 'p46', 'p39', 'p43', 'p42', 'p37', 'p45', 'p40', 'p41', 'p44', 'p38', 'p89', 'p94', 'p87', 'p92', 'p88', 'p93', 'p90', 'p86', 'p91', 'p140', 'p143', 'p141', 'p142', 'p181', 'p99', 'p30', 'p113', 'p137', 'p138', 'p135', 'p134', 'p136', 'p133', 'p144', 'p193', 'p194', 'p196', 'p4', 'p5', 'p10', 'p11', 'p68', 'p70', 'p69', 'p83', 'p80', 'p81', 'p82', 'p195', 'p1', 'p2', 'p198', 'p199', 'p3', 'p197', 'p7', 'p8', 'p9', 'p6', 'p14', 'p36', 'p150', 'p149', 'p95', 'p96', 'p98', 'p114', 'p152', 'p151', 'p168', 'p188', 'p192', 'p189', 'p190', 'p191', 'p35', 'p148', 'p169', 'p170', 'p173', 'p172', 'p174', 'p171', 'p76', 'p75', 'p77', 'p78', 'p74', 'p79', 'p72', 'p73', 'p65'] # O un orden específico como el mencionado
# # Filtro y ordenao el DataFrame según el order_key
# pTMscore = pTMscore_data[pTMscore_data['p'].isin(order_key)]
# pTMscore['p'] = pd.Categorical(pTMscore['p'], categories=order_key, ordered=True)
# pTMscore = pTMscore.sort_values('p').reset_index(drop=True)
# pTMscore
# Out:
# Loaded successfully.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_896\3587443423.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pTMscore['p'] = pd.Categorical(pTMscore['p'], categories=order_key, ordered=True)
#                                     Variant  pTMscore     p
# 0        NIST_p.Gln286Ala_Benign_report.txt      0.79  p115
# 1     NIST_p.Val59Asp_Pathogenic_report.txt      0.79   p13
# 2    NIST_p.Val270Arg_Pathogenic_report.txt      0.78  p105
# 3    NIST_p.Gln267Ala_Pathogenic_report.txt      0.79  p102
# 4    NIST_p.Gln267Lys_Pathogenic_report.txt      0.79  p101
# ..                                      ...       ...   ...
# 176  NIST_p.Ser200Arg_Pathogenic_report.txt      0.79   p74
# ...

# %%
import pandas as pd
pTMscore_data = fc.get_pTMscore(afxt_paths)
pTMscore_data['p'] = [f'p{i+1}' for i in range(199)]
# Nueva lista `order_key` con el prefijo "p" en cada valor
order_key = [f"p{num}" for num in [51, 148, 41, 38, 37, 42, 39, 40, 43, 44, 46, 45, 83, 169, 7, 21, 2, 75, 114, 113, 112, 111, 147, 163, 166, 167, 48, 47, 56, 52, 59, 53, 57, 54, 55, 58, 60, 81, 82, 119, 120, 121, 122, 151, 168, 118, 123, 161, 162, 68, 62, 66, 63, 61, 64, 65, 67, 89, 94, 91, 96, 97, 95, 93, 92, 90, 98, 102, 99, 100, 103, 101, 115, 164, 33, 36, 150, 20, 3, 116, 158, 157, 153, 155, 159, 156, 154, 152, 160, 181, 174, 178, 177, 172, 180, 175, 176, 179, 173, 25, 30, 23, 28, 24, 29, 26, 22, 27, 76, 79, 77, 78, 117, 35, 165, 49, 73, 74, 71, 70, 72, 69, 80, 129, 130, 132, 139, 140, 145, 146, 4, 6, 5, 19, 16, 17, 18, 131, 136, 137, 134, 135, 138, 133, 142, 143, 144, 141, 149, 171, 86, 85, 31, 32, 34, 50, 88, 87, 104, 124, 128, 125, 126, 127, 170, 84, 105, 106, 109, 108, 110, 107, 12, 11, 13, 14, 10, 15, 8, 9, 1]]
#Curado da datos a comparar: 
#order_key= [51, 148, 41, 38, 37, 42, 39, 40, 43, 44, 46, 45, 83, 169, 7, 21, 2, 75, 114, 113, 112, 111, 147, 163, 166, 167, 48, 47, 56, 52, 59, 53, 57, 54, 55, 58, 60, 81, 82, 119, 120, 121, 122, 151, 168, 118, 123, 161, 162, 68, 62, 66, 63, 61, 64, 65, 67, 89, 94, 91, 96, 97, 95, 93, 92, 90, 98, 102, 99, 100, 103, 101, 115, 164, 33, 36, 150, 20, 3, 116, 158, 157, 153, 155, 159, 156, 154, 152, 160, 181, 174, 178, 177, 172, 180, 175, 176, 179, 173, 25, 30, 23, 28, 24, 29, 26, 22, 27, 76, 79, 77, 78, 117, 35, 165, 49, 73, 74, 71, 70, 72, 69, 80, 129, 130, 132, 139, 140, 145, 146, 4, 6, 5, 19, 16, 17, 18, 131, 136, 137, 134, 135, 138, 133, 142, 143, 144, 141, 149, 171, 86, 85, 31, 32, 34, 50, 88, 87, 104, 124, 128, 125, 126, 127, 170, 84, 105, 106, 109, 108, 110, 107, 12, 11, 13, 14, 10, 15, 8, 9, 1]
# Filtro y ordenao el DataFrame según el order_key
pTMscore_AFL = pTMscore_data[pTMscore_data['p'].isin(order_key)]
pTMscore_AFL['p'] = pd.Categorical(pTMscore_AFL['p'], categories=order_key, ordered=True)
pTMscore_AFL = pTMscore_AFL.sort_values('p').reset_index(drop=True)
pTMscore_AFL

# %%
# Para instanciar los objetos prediction results directamente con la ruta del directorio completo se puede acceder:
results_CF = fc.instances_objects_CF('C:/Users/Admin/FoldComparative_cf2024/input/1.NIS_ColabFold_PREDICHAS-20240917T061608Z-001')
print("Dictionary of concatenated predictions:")
print(results_CF)
# Out:
# Loaded successfully.
# Loaded successfully.
# Loaded successfully.
# Loaded successfully.
# Loaded successfully.
# Loaded successfully.
# Loaded successfully.
# Loaded successfully.
# Loaded successfully.
# Loaded successfully.
# Loaded successfully.
# Loaded successfully.
# Loaded successfully.
# Loaded successfully.
# Dictionary of concatenated predictions:
# ...

# %% [markdown]
# ### Curado de Datos para la Comparación  de Variantes en orden alfabetico.
# Con el fin de obtener variantes comparadas en orden alfabetico , con la misma cantidad de predicciones por metodo.

# %%
#Ordenamos claves de predicciones en orden comparable: 
order_key=['p115','p13','p105','p102','p101','p106','p103','p104', 'p107', 'p108', 'p110', 'p109', 'p147', 'p34', 'p71', 'p85', 'p66', 'p139', 'p178', 'p177', 'p176', 'p175', 'p12', 'p28', 'p31', 'p32', 'p112', 'p111', 'p120', 'p116', 'p123', 'p117', 'p121', 'p118', 'p119', 'p122', 'p124', 'p145', 'p146', 'p183', 'p184', 'p185', 'p186', 'p16', 'p33', 'p182', 'p187', 'p26', 'p27', 'p132', 'p126', 'p130', 'p127', 'p125', 'p128', 'p129', 'p131', 'p153', 'p158', 'p155', 'p160', 'p161', 'p159', 'p157', 'p156', 'p154', 'p162', 'p166', 'p163', 'p164', 'p167', 'p165', 'p179', 'p29', 'p97', 'p100', 'p15', 'p84', 'p67', 'p180', 'p23', 'p22', 'p18', 'p20', 'p24', 'p21', 'p19', 'p17', 'p25', 'p46', 'p39', 'p43', 'p42', 'p37', 'p45', 'p40', 'p41', 'p44', 'p38', 'p89', 'p94', 'p87', 'p92', 'p88', 'p93', 'p90', 'p86', 'p91', 'p140', 'p143', 'p141', 'p142', 'p181', 'p99', 'p30', 'p113', 'p137', 'p138', 'p135', 'p134', 'p136', 'p133', 'p144', 'p193', 'p194', 'p196', 'p4', 'p5', 'p10', 'p11', 'p68', 'p70', 'p69', 'p83', 'p80', 'p81', 'p82', 'p195', 'p1', 'p2', 'p198', 'p199', 'p3', 'p197', 'p7', 'p8', 'p9', 'p6', 'p14', 'p36', 'p150', 'p149', 'p95', 'p96', 'p98', 'p114', 'p152', 'p151', 'p168', 'p188', 'p192', 'p189', 'p190', 'p191', 'p35', 'p148', 'p169', 'p170', 'p173', 'p172', 'p174', 'p171', 'p76', 'p75', 'p77', 'p78', 'p74', 'p79', 'p72', 'p73', 'p65']
print(len(order_key))
results_CF_sort=fc.sort_results(results_CF, order_key) 
print(results_CF_sort)
# Out:
# 181
# ...

# %%
#comparamos si se guardo en el orden "alpfabetico" establecido para todos los metodos:

# GUARDA usamos results_CF original por que se me enquilomba datos con metadata:
p1_CF= results_CF['p1']
print(f'Nombre NIS: ',{p1_CF.name})
print(f'Directorio:     ',{p1_CF.directory})
print(f'Tiempo de prediccion:        ',{p1_CF.time})
print(f'ptmscore:      ',{p1_CF.ptmscore})
#Este es p2 con orden original, con el cual no podemos aplicar metrcias
p2_CF=results_CF['p181']
print(f'Nombre NIS: ',{p2_CF.name})
print(f'Directorio:     ',{p2_CF.directory})
print(f'Tiempo de prediccion:        ',{p2_CF.time})
print(f'ptmscore:      ',{p2_CF.ptmscore})
#Este es el orden correcto de instancias de clases results_CF_sort para comparar con el resto de metodos predictivos
#Este es el orden correcto de instancias de clases results_CF_sort para comparar con el resto de metodos predictivos
p1= results_CF_sort['p1']
print(f'Nombre NIS: ',{p1.name})
print(f'Directorio:     ',{p1.directory})
print(f'Tiempo de prediccion:        ',{p1.time})
print(f'ptmscore:      ',{p1.ptmscore})

wt=results_CF_sort['p181']
print(f'Nombre NIS: ',{wt.name})
print(f'Directorio:     ',{wt.directory})
print(f'Tiempo de prediccion:        ',{wt.time})
print(f'ptmscore:      ',{wt.ptmscore})
# Out:
# Nombre NIS:  {'NIST_p.Thr354Ala_Pathogenic'}
# Directorio:      {'NIS_part__10_20240422214112/prediction_NIST_p.Thr354Ala_Pathogenic.zip'}
# Tiempo de prediccion:         {'769.5279619693756'}
# ptmscore:       {0}
# Nombre NIS:  {'NIST_p.Ile292Ala_Benign'}
# Directorio:      {'NIS_part__8_20240422210337/prediction_NIST_p.Ile292Ala_Benign.zip'}
# Tiempo de prediccion:         {'613.8683149814606'}
# ptmscore:       {0}
# Nombre NIS:  {'NIST_p.Ala180Thr_Benign'}
# Directorio:      {'NIS_part__4_20240422181735/prediction_NIST_p.Ala180Thr_Benign.zip'}
# Tiempo de prediccion:         {'641.9194612503052'}
# ptmscore:       {0}
# Nombre NIS:  {'NIST_wt'}
# Directorio:      {'NIS_part__1_20240422142541/prediction_NIST_wt.zip'}
# Tiempo de prediccion:         {'542.5194416046143'}
# ptmscore:       {0}

# %% [markdown]
# ### Matriz P

# %%
import numpy as np
import pandas as pd

# Esta funcion plotea una matriz Px[181*643 values]
plddt_values = wt.plot_plddt(results_CF_sort)

#Extraer solo  datos grafica
plddts_numpy=np.array(plddt_values)

#DataFrame
plddt_numpy_CF=pd.DataFrame(plddts_numpy)
# Out:
# C:\Users\Admin\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:170: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Primero se obtiene  el nombre de la proteina de referencia 
protein_names = []  # Lista vacía para almacenar los nombres de las proteínas
protein_names.append(wt.name)  # Asignar el nombre de la  proteína de referencia

# Si hay una segunda proteína (p2), por ejemplo p2 = results_CF_sort, agregarlo
if isinstance(results_CF_sort, dict):  # Si es un diccionario con múltiples predicciones
    for p in results_CF_sort.values():
        if p.name != wt.name:  # Evitar agregar el mismo nombre
            protein_names.append(p.name)

# Convertir la lista de nombres de proteínas a DataFrame

df_protein_names = pd.DataFrame(protein_names, columns=['Variant'])

df_protein_names = df_protein_names.assign(Algorithm='AFF-CF')

# Ya teniendo el arreglo numpy resultado de plot_plddt
# Convertir plddt_values a numpy array por las dudas, de este modo nos aseguramos el orden correcto
plddts_numpy = np.array(plddt_values)

# Crear un DataFrame para los valores pLDDT (asumiendo que las filas corresponden a las proteínas)
df_plddt_values = pd.DataFrame(plddts_numpy)

# Concatenar el DataFrame de nombres con el de valores pLDDT
Matriz_P_CF = pd.concat([df_protein_names, df_plddt_values], axis=1)

# Mostrar el DataFrame final en orden alfabetico menos la proteina de referencia (wild-type) que siempre aparece en primer posicion de la lista 
Matriz_P_CF
# Out:
#                          Variant Algorithm      0      1      2      3      4  \
# 0                        NIST_wt    AFF-CF  34.00  25.12  26.55  34.22  30.80
# 1        NIST_p.Ala180Thr_Benign    AFF-CF  32.91  27.16  28.47  36.06  29.70
# 2        NIST_p.Ala364Gly_Benign    AFF-CF  36.09  28.73  28.31  36.22  28.48
# 3    NIST_p.Arg124Ala_Pathogenic    AFF-CF  34.69  27.89  28.59  35.91  30.20
# 4    NIST_p.Arg124Asn_Pathogenic    AFF-CF  28.36  26.53  28.73  35.69  29.39
# ..                           ...       ...    ...    ...    ...    ...    ...
# 176   NIST_p.Val59Glu_Pathogenic    AFF-CF  33.16  26.36  27.92  35.41  29.03
# 177       NIST_p.Val59Ile_Benign    AFF-CF  36.31  27.92  28.12  35.56  29.06
# 178   NIST_p.Val59Lys_Pathogenic    AFF-CF  35.62  27.47  28.09  35.53  28.38
# 179   NIST_p.Val59Pro_Pathogenic    AFF-CF  34.91  27.84  28.66  35.47  34.94
# 180       NIST_p.Val59Thr_Benign    AFF-CF  37.62  26.64  29.77  35.31  32.91
#
# ...

# %% [markdown]
# # Comparative Metrics:

# %% [markdown]
# ## REF_METRICS (AFF)

# %%
results_AFF = fc.load_REF('C:/Users/Admin/FoldComparative_cf2024/input/NIST_AWS_Full_AF_20230926.afxt')
print(results_AFF)
# Out:
# Loaded successfully.
# ...

# %%
#Corroboro el mismo orden entre metricas a comparar 
# GUARDA usamos results_CF original por que se me enquilomba datos con metadata:
p1_AFF= results_AFF['REF_p1']
print(f'Nombre NIS: ',{p1_AFF.name})
print(f'Directorio:     ',{p1_AFF.directory})
print(f'Tiempo de prediccion:        ',{p1_AFF.time})
print(f'ptmscore:      ',{p1_AFF.ptmscore})

p1_CF= results_CF_sort['p1']
print(f'Nombre NIS: ',{p1_CF.name})
print(f'Directorio:     ',{p1_CF.directory})
print(f'Tiempo de prediccion:        ',{p1_CF.time})
print(f'ptmscore:      ',{p1_CF.ptmscore})

#Este es el orden correcto de instancias de clases results_CF_sort para comparar con el resto de metodos predictivos


#Este es el orden correcto de instancias de clases results_CF_sort para comparar con el resto de metodos predictivos
p181_AFF= results_AFF['REF_p181']
print(f'Nombre NIS: ',{p181_AFF.name})
print(f'Directorio:     ',{p181_AFF.directory})
print(f'Tiempo de prediccion:        ',{p181_AFF.time})
print(f'ptmscore:      ',{p181_AFF.ptmscore})

p181= results_CF_sort['p181']
print(f'Nombre NIS: ',{p181.name})
print(f'Directorio:     ',{p181.directory})
print(f'Tiempo de prediccion:        ',{p181.time})
print(f'ptmscore:      ',{p181.ptmscore})
# Out:
# Nombre NIS:  {'NIST_pAla180Thr_Benign'}
# Directorio:      {'NIST_AWS_Full_AF_20230926/prediction_NIST_pAla180Thr_Benign.zip'}
# Tiempo de prediccion:         {'648.2174463272095'}
# ptmscore:       {0}
# Nombre NIS:  {'NIST_p.Ala180Thr_Benign'}
# Directorio:      {'NIS_part__4_20240422181735/prediction_NIST_p.Ala180Thr_Benign.zip'}
# Tiempo de prediccion:         {'641.9194612503052'}
# ptmscore:       {0}
# Nombre NIS:  {'NIST_wt'}
# Directorio:      {'NIST_AWS_Full_AF_20230926/prediction_NIST_wt.zip'}
# Tiempo de prediccion:         {'643.5429110527039'}
# ptmscore:       {0}
# Nombre NIS:  {'NIST_wt'}
# Directorio:      {'NIS_part__1_20240422142541/prediction_NIST_wt.zip'}
# Tiempo de prediccion:         {'542.5194416046143'}
# ptmscore:       {0}

# %% [markdown]
# ## Extracción de archivos PDB para la superposicion de coordenadas 3D.

# %%
p1_CF.get_pdbs(results_CF_sort)

# %%
# Definir rutas y umbral
aff_dir = 'C:\\Users\\Admin\\FoldComparative_cf2024\\pdb_files_AFF'
cf_dir = 'C:\\Users\\Admin\\FoldComparative_cf2024\\pdb_files_CF'
output_superimposed_dir = 'C:\\Users\\Admin\\FoldComparative_cf2024\\pdb_files_superimposed'
output_no_aligned_dir = 'C:\\Users\\Admin\\FoldComparative_cf2024\\pdb_files_no_aligned'
threshold = 70.0  # Ajusta el umbral según tus necesidades

# Procesar todos los pares de archivos PDB
fc.process_pdb_pairs(
    aff_dir,
    cf_dir,
    output_superimposed_dir,
    output_no_aligned_dir,
    threshold
)
# Out:
# Lista de IDs de residuos predichos alineados (pLDDT ≥ 70.0):
# ...

# %%
#Perfil de disancias Ca entre la misma proteina predicha por dos predictores distintos: 
p1_AFF='C:/Users/Admin/FoldComparative_cf2024/pdb_files_AFF/NIST_pAla180Thr_Benign_relaxed.pdb'
p1_CF_fit='C:/Users/Admin/FoldComparative_cf2024/pdb_files_superimposed/NIST_pAla180Thr_Benign_relaxed_superimposed.pdb'
rmsd_p1=fc.aadistances_rmsd(p1_AFF, p1_CF_fit,start=0, end=0,plot=True)
# Out:
# Global RMSD: 4.78 Å

# %%
import pandas as pd
# Función para iterar sobre todos los archivos y crear el DataFrame
def create_combined_distances_df(aff_dir, fit_cf_dir):
    # Obtengo archivos PDB en ambos directorios
    aff_files = sorted([f for f in os.listdir(aff_dir) if f.endswith('.pdb')])
    fit_cf_files = sorted([f for f in os.listdir(fit_cf_dir) if f.endswith('.pdb')])

    # Verifico que ambos directorios tengan el mismo número de archivos
    if len(aff_files) != len(fit_cf_files):
        raise ValueError("Los directorios no tienen el mismo número de archivos PDB.")

    # Crear un DataFrame vacío para almacenar las distancias
    combined_df = pd.DataFrame()

    # Iterar sobre los archivos y calcular las distancias
    for i, (aff_file, fit_cf_file) in enumerate(zip(aff_files, fit_cf_files)):
        p1_AFF = os.path.join(aff_dir, aff_file)
        p1_fit_CF = os.path.join(fit_cf_dir, fit_cf_file)
        
        # Calcular distancias para el par actual de archivos
        distances = fc.calc_distances(p1_AFF, p1_fit_CF)

        # Agregar el resultado como una nueva fila al DataFrame
        combined_df = pd.concat([combined_df, distances.to_frame().T], ignore_index=True)

    # Renombrar las columnas con las posiciones de CA
    combined_df.columns = [f'αC_{i}' for i in range(1, combined_df.shape[1] + 1)]
    
    return combined_df
# Directorios
aff_dir = 'C:/Users/Admin/FoldComparative_cf2024/pdb_files_AFF/'
fit_cf_dir = 'C:/Users/Admin/FoldComparative_cf2024/pdb_files_superimposed_CF'

# Crear el DataFrame combinado
df_distances = create_combined_distances_df(aff_dir, fit_cf_dir)

# Mostrar el DataFrame resultante
df_distances
# Out:
#           αC_1       αC_2       αC_3       αC_4       αC_5      αC_6  \
# 0    28.756926  26.646286  21.280643  14.324045  12.103946  7.761867
# 1    28.955442  26.431274  20.857830  14.825306  11.452189  6.970750
# 2    30.464684  27.237507  21.378435  15.640203  12.153485  6.326456
# 3    28.727667  25.376860  19.805597  13.518953  11.614128  7.631810
# 4    28.467896  26.849983  21.293394  14.549765  12.379689  8.080453
# ..         ...        ...        ...        ...        ...       ...
# 176  30.691097  27.168905  22.275049  15.742635  10.425823  6.118268
# 177  28.968920  26.646593  20.951452  14.317767  11.757051  7.588783
# 178  28.701244  27.029711  21.551004  14.651921  12.087508  6.778924
# 179  28.226719  26.400724  20.326271  13.708361  11.145323  6.974755
# 180   8.171146   6.912533   8.338889   2.967561   3.427850  4.614466
#
#          αC_7      αC_8      αC_9     αC_10  ...     αC_634     αC_635  \
# ...

# %%
MetaData=Matriz_P_CF[['Variant','Algorithm']]
#ordenar alfabeticamente ya que el directorio de pdbs se se encuentran asi
MetaData=MetaData.sort_values(by='Variant')
Distances_CF_HC=pd.concat([MetaData,df_distances],axis=1)
Distances_CF_HC
# Out:
#                          Variant Algorithm       αC_1       αC_2       αC_3  \
# 1        NIST_p.Ala180Thr_Benign    AFF-CF  28.955442  26.431274  20.857830
# 2        NIST_p.Ala364Gly_Benign    AFF-CF  30.464684  27.237507  21.378435
# 3    NIST_p.Arg124Ala_Pathogenic    AFF-CF  28.727667  25.376860  19.805597
# 4    NIST_p.Arg124Asn_Pathogenic    AFF-CF  28.467896  26.849983  21.293394
# 5    NIST_p.Arg124Asp_Pathogenic    AFF-CF  30.338457  27.250872  21.251060
# ..                           ...       ...        ...        ...        ...
# 177       NIST_p.Val59Ile_Benign    AFF-CF  28.968920  26.646593  20.951452
# 178   NIST_p.Val59Lys_Pathogenic    AFF-CF  28.701244  27.029711  21.551004
# 179   NIST_p.Val59Pro_Pathogenic    AFF-CF  28.226719  26.400724  20.326271
# 180       NIST_p.Val59Thr_Benign    AFF-CF   8.171146   6.912533   8.338889
# 0                        NIST_wt    AFF-CF  28.756926  26.646286  21.280643
#
# ...

# %%
#Guardamos Matriz P para visualizar resultados. 
# Distances_CF_HC.to_csv('Distances_CF_HC.csv', index=False)

# %%
# Seleccionamos las columnas que contienen los átomos de carbono alfa (αC_1, αC_2, ..., αC_643)
columnas_alfa = [col for col in Distances_CF_HC.columns if 'αC_' in col]

# Calculamos el RMSD global como la media de los valores en las columnas αC
Distances_CF_HC['RMSD_global'] = df_distances.mean(axis=1)
# Crear el DataFrame final
RMSD_global_CF = Distances_CF_HC[['Variant', 'Algorithm', 'RMSD_global']]

RMSD_global_CF
# Out:
#                          Variant Algorithm  RMSD_global
# 1        NIST_p.Ala180Thr_Benign    AFF-CF     3.754032
# 2        NIST_p.Ala364Gly_Benign    AFF-CF     3.345101
# 3    NIST_p.Arg124Ala_Pathogenic    AFF-CF     5.283157
# 4    NIST_p.Arg124Asn_Pathogenic    AFF-CF     5.345973
# 5    NIST_p.Arg124Asp_Pathogenic    AFF-CF     3.607840
# ..                           ...       ...          ...
# 177       NIST_p.Val59Ile_Benign    AFF-CF     4.855410
# 178   NIST_p.Val59Lys_Pathogenic    AFF-CF     4.193166
# 179   NIST_p.Val59Pro_Pathogenic    AFF-CF     5.395072
# 180       NIST_p.Val59Thr_Benign    AFF-CF     5.122554
# 0                        NIST_wt    AFF-CF     4.775545
#
# [181 rows x 3 columns]

# %%
# Mostrar el resultado
RMSD_global_CF.to_csv('C:/Users/Admin/FoldComparative_cf2024/Metrics_DF/RMSD_global_CF.csv',index=False)

# %%
# Ejemplo de uso:

directorio_AFF = 'C:/Users/Admin/FoldComparative_cf2024/pdb_files_AFF'
directorio_CF ='C:/Users/Admin/FoldComparative_cf2024/pdb_files_superimposed'
name_col = 'TM(AFF-CF)'  # Nombre de la columna personalizada

tmscore_AFF_CF = fc.calc_tmscore_for_directories(directorio_AFF, directorio_CF, name=name_col)
tmscore_AFF_CF
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8140\3378555785.py:102: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_tmscore = pd.concat([df_tmscore, pd.DataFrame({'Variant': [ref_file], name: [tm_scores[0]]})], ignore_index=True)
#                                     Variant  TM(AFF-CF)
# 0        NIST_pAla180Thr_Benign_relaxed.pdb    0.844608
# 1        NIST_pAla364Gly_Benign_relaxed.pdb    0.849749
# 2    NIST_pArg124Ala_Pathogenic_relaxed.pdb    0.853492
# 3    NIST_pArg124Asn_Pathogenic_relaxed.pdb    0.849078
# 4    NIST_pArg124Asp_Pathogenic_relaxed.pdb    0.847462
# ..                                      ...         ...
# 176       NIST_pVal59Ile_Benign_relaxed.pdb    0.847036
# ...

# %% [markdown]
# # Calculo D (AFL - CF)

# %%
import os
import pandas as pd
pdb_AFL='C:/Users/Admin/FoldComparative_cf2024/pdb_files_AFL'
pdb_CF_AFL_superimposed='C:/Users/Admin/FoldComparative_cf2024/'
pdb_AF3_AFL_superimposed='C:/Users/Admin/FoldComparative_cf2024/'

# %%
#superimposicion de matrices:
# Definir rutas y umbral
ref_dir = 'C:\\Users\\Admin\\FoldComparative_cf2024\\pdb_files_AFL'
cf_dir = 'C:\\Users\\Admin\\FoldComparative_cf2024\\pdb_files_CF'
output_superimposed_dir = 'C:\\Users\\Admin\\FoldComparative_cf2024\\pdb_files_CF_AFL_superimposed'
output_no_aligned_dir = 'C:\\Users\\Admin\\FoldComparative_cf2024\\pdb_files_CF_AFL_no_aligned'
threshold = 70.0  # Ajusta el umbral según tus necesidades

# Procesar todos los pares de archivos PDB
fc.process_pdb_pairs(
    ref_dir,
    cf_dir,
    output_superimposed_dir,
    output_no_aligned_dir,
    threshold
)
# Out:
# Lista de IDs de residuos predichos alineados (pLDDT ≥ 70.0):
# ...

# %%
from Bio.PDB import PDBParser
import numpy as np
import os
import pandas as pd


def calc_distances(p1_AFF, p1_fit_CF, start=0, end=0, plot=False):
    # Código de la función calc_distances (tu versión original)
    parser = PDBParser(QUIET=True)
    structure_exp = parser.get_structure('exp', p1_AFF)
    structure_pred = parser.get_structure('pred', p1_fit_CF)

    ref_atoms_coords = []
    sample_atoms_coords = []
    rmsd_individual = []

    for exp_chain in structure_exp.get_chains():
        for exp_res in exp_chain.get_residues():
            if exp_res.has_id('CA'):
                exp_res_id = exp_res.get_id()[1]
                for pred_chain in structure_pred.get_chains():
                    for pred_res in pred_chain.get_residues():
                        pred_res_id = pred_res.get_id()[1]
                        if pred_res_id == exp_res_id and pred_res.has_id('CA'):
                            ref_atoms_coords.append(exp_res['CA'].get_coord())
                            sample_atoms_coords.append(pred_res['CA'].get_coord())
                            break

    if not ref_atoms_coords or not sample_atoms_coords:
        raise ValueError("No se encontraron átomos CA alineados.")

    if end == 0:
        end = len(ref_atoms_coords)

    for i in range(start, end):
        if i < len(ref_atoms_coords) and i < len(sample_atoms_coords):
            dist = np.sqrt(np.sum((ref_atoms_coords[i] - sample_atoms_coords[i]) ** 2))
            rmsd_individual.append(dist)

    return pd.Series(rmsd_individual)

# Función para iterar sobre todos los archivos y crear el DataFrame
def create_combined_distances_df(aff_dir, fit_cf_dir):
    # Obtener lista de archivos PDB en ambos directorios
    aff_files = sorted([f for f in os.listdir(aff_dir) if f.endswith('.pdb')])
    fit_cf_files = sorted([f for f in os.listdir(fit_cf_dir) if f.endswith('.pdb')])

    # Verificar que ambos directorios tengan el mismo número de archivos
    if len(aff_files) != len(fit_cf_files):
        raise ValueError("Los directorios no tienen el mismo número de archivos PDB.")

    # Crear un DataFrame vacío para almacenar las distancias
    combined_df = pd.DataFrame()

    # Iterar sobre los archivos y calcular las distancias
    for i, (aff_file, fit_cf_file) in enumerate(zip(aff_files, fit_cf_files)):
        p1_AFF = os.path.join(aff_dir, aff_file)
        p1_fit_CF = os.path.join(fit_cf_dir, fit_cf_file)
        
        # Calcular distancias para el par actual de archivos
        distances = calc_distances(p1_AFF, p1_fit_CF)

        # Agregar el resultado como una nueva fila al DataFrame
        combined_df = pd.concat([combined_df, distances.to_frame().T], ignore_index=True)

    # Renombrar las columnas con las posiciones de CA
    combined_df.columns = [f'αC_{i}' for i in range(1, combined_df.shape[1] + 1)]
    
    return combined_df

# %%
dir_pdb_AFL='C:/Users/Admin/FoldComparative_cf2024/pdb_files_AFL'
dir_pdb_AF3_AFL_superimposed='C:\\Users\\Admin\\FoldComparative_cf2024\\pdb_files_CF_AFL_superimposed'
# Crear el DataFrame combinado
df_concat_distances = fc.create_combined_distances_df(dir_pdb_AFL, dir_pdb_AF3_AFL_superimposed)

# Mostrar el DataFrame resultante
df_concat_distances
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[26], line 4
#       2 dir_pdb_AF3_AFL_superimposed='C:\\Users\\Admin\\FoldComparative_cf2024\\pdb_files_CF_AFL_superimposed'
#       3 # Crear el DataFrame combinado
# ----> 4 df_concat_distances = fc.create_combined_distances_df(dir_pdb_AFL, dir_pdb_AF3_AFL_superimposed)
#       6 # Mostrar el DataFrame resultante
#       7 df_concat_distances
#
# File C:\Users/Admin/FoldComparative_cf2024/AlphaFoldXplore_cf2024\fold_comparative.py:1178, in create_combined_distances_df(ref_dir, fit_x_dir)
#    1175 p1_fit_CF = os.path.join(fit_x_dir, fit_x_file)
#    1177 # Calcula las distancias para el par actual de archivos.
# -> 1178 distances = calc_distances(ref_dir, fit_x_dir)
#    1180 # Agrega el resultado como una nueva fila al DataFrame combinado.
# ...

# %%
dir_pdb_AFL='C:/Users/Admin/FoldComparative_cf2024/pdb_files_AFL'
dir_pdb_AF3_AFL_superimposed='C:\\Users\\Admin\\FoldComparative_cf2024\\pdb_files_CF_AFL_superimposed'
# Crear el DataFrame combinado
df_concat_distances = create_combined_distances_df(dir_pdb_AFL, dir_pdb_AF3_AFL_superimposed)

# Mostrar el DataFrame resultante
df_concat_distances
# Out:
#           αC_1       αC_2       αC_3       αC_4       αC_5      αC_6  \
# 0    28.851082  26.548523  20.870461  14.310981  12.232637  8.012934
# 1    28.354517  25.427155  19.816711  13.555239  10.936672  7.532145
# 2    27.794815  25.868662  20.438858  13.639456  11.530857  7.708928
# 3    28.615778  25.784945  20.878508  13.843677  11.973700  7.664358
# 4    28.950174  27.204260  21.626793  14.893641  12.608626  8.168068
# ..         ...        ...        ...        ...        ...       ...
# 176  29.457464  26.412352  21.258224  14.306050  11.501703  7.483035
# 177  27.844749  24.894329  18.818687  13.519693  10.745957  7.130183
# 178  29.122185  28.195774  22.252567  15.439881  13.432523  8.036744
# 179  28.974764  27.257689  21.531235  14.469049  11.927449  7.384072
# 180   8.830680   7.962948   9.269821   4.075190   4.691442  4.990387
#
#          αC_7      αC_8      αC_9     αC_10  ...     αC_634     αC_635  \
# ...

# %%
#agrego fmetadata: 

MetaData=MatrixP_CF[['Variant','Algorithm']]
Distances_CF_AFL_HC=pd.concat([MetaData,df_concat_distances],axis=1)
Distances_CF_AFL_HC['Algorithm']=Distances_CF_AFL_HC['Algorithm'].replace({'CF':'AFL-CF'})
Distances_CF_AFL_HC
# Out:
#     NIS_Variant Algorithm        Type       αC_1       αC_2       αC_3  \
# 0     Ala180Thr    AFL-CF      Benign  28.851082  26.548523  20.870461
# 1     Ala364Gly    AFL-CF      Benign  28.354517  25.427155  19.816711
# 2     Arg124Ala    AFL-CF  Pathogenic  27.794815  25.868662  20.438858
# 3     Arg124Asn    AFL-CF  Pathogenic  28.615778  25.784945  20.878508
# 4     Arg124Asp    AFL-CF  Pathogenic  28.950174  27.204260  21.626793
# ..          ...       ...         ...        ...        ...        ...
# 176    Val59Ile    AFL-CF      Benign  29.457464  26.412352  21.258224
# 177    Val59Lys    AFL-CF  Pathogenic  27.844749  24.894329  18.818687
# 178    Val59Pro    AFL-CF  Pathogenic  29.122185  28.195774  22.252567
# 179    Val59Thr    AFL-CF      Benign  28.974764  27.257689  21.531235
# 180   Wild-Type    AFL-CF   Wild-Type   8.830680   7.962948   9.269821
#
#           αC_4       αC_5      αC_6      αC_7  ...     αC_634     αC_635  \
# ...

# %%
Distances_CF_AFL_HC.to_csv('C:/Users/Admin/FoldComparative_cf2024/Metrics_DF/Distances_CF_AFL_HC.csv',index=False)

# %%
import pandas as pd

# Seleccionamos las columnas que contienen los átomos de carbono alfa (αC_1, αC_2, ..., αC_643)
columnas_alfa = [col for col in df_concat_distances.columns if 'αC_' in col]

# Calculamos el RMSD global como la media de los valores en las columnas αC
Distances_CF_AFL_HC['RMSD_global'] = df_concat_distances.mean(axis=1)
# Crear el DataFrame final
RMSD_global_CF_AFL = Distances_CF_AFL_HC[['NIS_Variant', 'Algorithm', 'Type', 'RMSD_global']]
RMSD_global_CF_AFL
# Out:
#     NIS_Variant Algorithm        Type  RMSD_global
# 0     Ala180Thr    AFL-CF      Benign     4.572013
# 1     Ala364Gly    AFL-CF      Benign     4.661500
# 2     Arg124Ala    AFL-CF  Pathogenic     4.426688
# 3     Arg124Asn    AFL-CF  Pathogenic     4.390147
# 4     Arg124Asp    AFL-CF  Pathogenic     2.755905
# ..          ...       ...         ...          ...
# 176    Val59Ile    AFL-CF      Benign     4.979296
# 177    Val59Lys    AFL-CF  Pathogenic     2.485565
# 178    Val59Pro    AFL-CF  Pathogenic     5.230503
# 179    Val59Thr    AFL-CF      Benign     5.403425
# 180   Wild-Type    AFL-CF   Wild-Type     4.864973
#
# [181 rows x 4 columns]

# %%
RMSD_global_CF_AFL.to_csv('C:/Users/Admin/FoldComparative_cf2024/Metrics_DF/RMSD_AFL_CF.csv',index=False)

# %%
name_col = 'TM(AFL-CF)'  # Nombre de la columna personalizada

TM_AFL_CF = fc.calc_tmscore_for_directories(dir_pdb_AFL, dir_pdb_AF3_AFL_superimposed, name=name_col)
TM_AFL_CF
# Out:
# C:\Users/Admin/FoldComparative_cf2024/AlphaFoldXplore_cf2024\fold_comparative.py:1135: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_tmscore = pd.concat([df_tmscore, pd.DataFrame({'Variant': [ref_file], name: [tm_scores[0]]})], ignore_index=True)
#                                       Variant  TM(AFL-CF)
# 0        NIST_pAla180Thr_Benign_unrelaxed.pdb    0.849070
# 1        NIST_pAla364Gly_Benign_unrelaxed.pdb    0.846698
# 2    NIST_pArg124Ala_Pathogenic_unrelaxed.pdb    0.849209
# 3    NIST_pArg124Asn_Pathogenic_unrelaxed.pdb    0.847803
# 4    NIST_pArg124Asp_Pathogenic_unrelaxed.pdb    0.851707
# ..                                        ...         ...
# 176       NIST_pVal59Ile_Benign_unrelaxed.pdb    0.844362
# ...

# %%
TM_AFL_CF.to_csv('C:/Users/Admin/FoldComparative_cf2024/Metrics_DF/TM_AFL_CF.csv',index=False)

# %% [markdown]
# # Calculo D (AFL - AF3)

# %%
# Definir rutas y umbral
ref_dir = 'C:\\Users\\Admin\\FoldComparative_cf2024\\pdb_files_AFL'
af3_dir = 'C:\\Users\\Admin\\FoldComparative_cf2024\\pdb_files_AF3'
output_superimposed_dir = 'C:\\Users\\Admin\\FoldComparative_cf2024\\pdb_files_AF3_AFL_superimposed'
output_no_aligned_dir = 'C:\\Users\\Admin\\FoldComparative_cf2024\\pdb_files_CF_AF3_no_aligned'
threshold = 70.0  # Ajusta el umbral según tus necesidades

# Procesar todos los pares de archivos PDB
fc.process_pdb_pairs(
    ref_dir,
    af3_dir,
    output_superimposed_dir,
    output_no_aligned_dir,
    threshold
)
# Out:
# Lista de IDs de residuos predichos alineados (pLDDT ≥ 70.0):
# ...

# %%
# Directorios donde se encuentran los archivos PDB.
ref_dir = 'C:/Users/Admin/FoldComparative_cf2024/pdb_files_AFL/'
superimposed_af3_dir = 'C:/Users/Admin/FoldComparative_cf2024/pdb_files_AF3_AFL_superimposed/'

# Crear el DataFrame combinado con todas las distancias calculadas.
df_concat_distances = create_combined_distances_df(ref_dir, superimposed_af3_dir)

# Mostrar el DataFrame resultante.
df_concat_distances
# Out:
#           αC_1       αC_2       αC_3       αC_4      αC_5      αC_6      αC_7  \
# 0     4.371358   3.947283   3.509176   2.135139  1.483555  1.653764  1.284138
# 1    24.478474  17.861219  15.938266  11.321694  6.154325  4.192120  2.441775
# 2     3.156176   2.304718   2.268803   1.882149  1.218231  1.194261  1.308441
# 3     0.330253   1.024681   1.346761   1.294267  1.637433  0.812040  0.298029
# 4     5.642020   6.185578   5.089799   2.157131  1.847446  1.753592  1.057486
# ..         ...        ...        ...        ...       ...       ...       ...
# 176   2.610012   2.793729   4.620200   1.921100  1.320609  1.132901  1.343746
# 177   4.874095   5.590253   6.607191   2.714146  2.108541  1.755056  1.423066
# 178   3.201543   3.555682   6.192160   3.050622  3.543102  4.380770  2.930865
# 179  20.941217  15.377579  14.397436   8.973856  6.501348  5.582408  1.022731
# 180  10.543411  10.719234   8.065642   4.977906  4.299626  4.026299  2.146597
#
# ...

# %%
#agrego fmetadata: 
MatrixP_CF=pd.read_csv('C:/Users/Admin/FoldComparative_cf2024/Metrics_DF/MatrixP_CF.csv')
MatrixP_CF[['NIS_Variant','Algorithm','Type']]

MetaData=MatrixP_CF[['NIS_Variant','Algorithm','Type']]
Distances_AF3_AFL_HC=pd.concat([MetaData,df_concat_distances],axis=1)
Distances_AF3_AFL_HC['Algorithm']=Distances_CF_AFL_HC['Algorithm'].replace({'CF':'AFL-AF3'})
Distances_AF3_AFL_HC
# Out:
#     NIS_Variant Algorithm        Type       αC_1       αC_2       αC_3  \
# 0     Ala180Thr    AFL-CF      Benign   4.371358   3.947283   3.509176
# 1     Ala364Gly    AFL-CF      Benign  24.478474  17.861219  15.938266
# 2     Arg124Ala    AFL-CF  Pathogenic   3.156176   2.304718   2.268803
# 3     Arg124Asn    AFL-CF  Pathogenic   0.330253   1.024681   1.346761
# 4     Arg124Asp    AFL-CF  Pathogenic   5.642020   6.185578   5.089799
# ..          ...       ...         ...        ...        ...        ...
# 176    Val59Ile    AFL-CF      Benign   2.610012   2.793729   4.620200
# 177    Val59Lys    AFL-CF  Pathogenic   4.874095   5.590253   6.607191
# 178    Val59Pro    AFL-CF  Pathogenic   3.201543   3.555682   6.192160
# 179    Val59Thr    AFL-CF      Benign  20.941217  15.377579  14.397436
# 180   Wild-Type    AFL-CF   Wild-Type  10.543411  10.719234   8.065642
#
#           αC_4      αC_5      αC_6      αC_7  ...     αC_634      αC_635  \
# ...

# %%
Distances_AF3_AFL_HC.to_csv('C:/Users/Admin/FoldComparative_cf2024/Metrics_DF/Distances_AF3_AFL_HC.csv',index=False)

# %%
# Seleccionamos las columnas que contienen los átomos de carbono alfa (αC_1, αC_2, ..., αC_643)

columnas_alfa = [col for col in Distances_AF3_AFL_HC.columns if 'αC_' in col]

# Calculamos el RMSD global como la media de los valores en las columnas αC
Distances_AF3_AFL_HC['RMSD_global'] = df_concat_distances.mean(axis=1)
# Crear el DataFrame final
RMSD_AF3_AFL = Distances_AF3_AFL_HC[['NIS_Variant', 'Algorithm', 'Type', 'RMSD_global']]
RMSD_AF3_AFL
# Out:
#     NIS_Variant Algorithm        Type  RMSD_global
# 0     Ala180Thr    AFL-CF      Benign     3.565735
# 1     Ala364Gly    AFL-CF      Benign     7.206348
# 2     Arg124Ala    AFL-CF  Pathogenic     6.808799
# 3     Arg124Asn    AFL-CF  Pathogenic     6.317142
# 4     Arg124Asp    AFL-CF  Pathogenic     5.712321
# ..          ...       ...         ...          ...
# 176    Val59Ile    AFL-CF      Benign     3.310479
# 177    Val59Lys    AFL-CF  Pathogenic     5.330444
# 178    Val59Pro    AFL-CF  Pathogenic     5.318399
# 179    Val59Thr    AFL-CF      Benign     6.584160
# 180   Wild-Type    AFL-CF   Wild-Type     6.347633
#
# [181 rows x 4 columns]

# %%
RMSD_AF3_AFL.to_csv('C:/Users/Admin/FoldComparative_cf2024/Metrics_DF/RMSD_AF3_AFL.csv',index=False)

# %%
ref_dir = 'C:/Users/Admin/FoldComparative_cf2024/pdb_files_AFL/'
superimposed_af3_dir = 'C:/Users/Admin/FoldComparative_cf2024/pdb_files_AF3_AFL_superimposed/'
name_col = 'TM(AFL-AF3)'  # Nombre de la columna personalizada
TM_AFL_AF3 = fc.calc_tmscore_for_directories(ref_dir, superimposed_af3_dir, name=name_col)
TM_AFL_AF3
# Out:
# C:\Users/Admin/FoldComparative_cf2024/AlphaFoldXplore_cf2024\fold_comparative.py:1135: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_tmscore = pd.concat([df_tmscore, pd.DataFrame({'Variant': [ref_file], name: [tm_scores[0]]})], ignore_index=True)
#                                       Variant  TM(AFL-AF3)
# 0        NIST_pAla180Thr_Benign_unrelaxed.pdb     0.840284
# 1        NIST_pAla364Gly_Benign_unrelaxed.pdb     0.820106
# 2    NIST_pArg124Ala_Pathogenic_unrelaxed.pdb     0.847338
# 3    NIST_pArg124Asn_Pathogenic_unrelaxed.pdb     0.842865
# 4    NIST_pArg124Asp_Pathogenic_unrelaxed.pdb     0.849419
# ..                                        ...          ...
# 176       NIST_pVal59Ile_Benign_unrelaxed.pdb     0.844863
# ...

# %%
TM_AFL_AF3.to_csv('C:/Users/Admin/FoldComparative_cf2024/Metrics_DF/TM_AFL_AF3.csv',index=False)
